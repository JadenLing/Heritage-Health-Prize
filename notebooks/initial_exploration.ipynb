# %% [markdown]
# ## Initial Exploration

# %%
import pandas as pd
import numpy as np

# %%
# Define the path to your directory containing the CSV files
file_path = "../data/raw/HHP_release3/"

# Load each file into a DataFrame
claims_df = pd.read_csv(f"{file_path}Claims.csv")
days_in_hospital_y2_df = pd.read_csv(f"{file_path}DaysInHospital_Y2.csv")
days_in_hospital_y3_df = pd.read_csv(f"{file_path}DaysInHospital_Y3.csv")
drug_count_df = pd.read_csv(f"{file_path}DrugCount.csv")
lab_count_df = pd.read_csv(f"{file_path}LabCount.csv")
lookup_primary_condition_group_df = pd.read_csv(f"{file_path}Lookup PrimaryConditionGroup.csv")
lookup_procedure_group_df = pd.read_csv(f"{file_path}Lookup ProcedureGroup.csv")
members_df = pd.read_csv(f"{file_path}Members.csv")
target_df = pd.read_csv(f"{file_path}Target.csv")

# %%
claims_df.columns
# Out:
# Index(['MemberID', 'ProviderID', 'Vendor', 'PCP', 'Year', 'Specialty',
#        'PlaceSvc', 'PayDelay', 'LengthOfStay', 'DSFS', 'PrimaryConditionGroup',
#        'CharlsonIndex', 'ProcedureGroup', 'SupLOS'],
#       dtype='object')

# %%
claims_df.head()
# Out:
#    MemberID  ProviderID    Vendor      PCP Year   Specialty  \
# 0  42286978   8013252.0  172193.0  37796.0   Y1     Surgery
# 1  97903248   3316066.0  726296.0   5300.0   Y3    Internal
# 2   2759427   2997752.0  140343.0  91972.0   Y3    Internal
# 3  73570559   7053364.0  240043.0  70119.0   Y3  Laboratory
# 4  11837054   7557061.0  496247.0  68968.0   Y2     Surgery
#
#               PlaceSvc PayDelay LengthOfStay         DSFS  \
# 0               Office       28          NaN  8- 9 months
# 1               Office       50          NaN  7- 8 months
# 2               Office       14          NaN   0- 1 month
# 3      Independent Lab       24          NaN  5- 6 months
# 4  Outpatient Hospital       27          NaN  4- 5 months
#
#   PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 0               NEUMENT             0            MED       0
# 1               NEUMENT           1-2             EM       0
# 2                METAB3             0             EM       0
# 3                METAB3           1-2            SCS       0
# 4               FXDISLC           1-2             EM       0

# %%
claims_df.loc[claims_df["Vendor"] == 172193.0]
# Out:
#          MemberID  ProviderID    Vendor      PCP Year Specialty PlaceSvc  \
# 0        42286978   8013252.0  172193.0  37796.0   Y1   Surgery   Office
# 1464     88875839   6026848.0  172193.0  96614.0   Y2   Surgery   Office
# 2422     90572264   2410265.0  172193.0  20893.0   Y3   Surgery   Office
# 3400     91315982   8013252.0  172193.0  90575.0   Y1   Surgery   Office
# 3962     68249807   1325703.0  172193.0  21146.0   Y3   Surgery   Office
# ...           ...         ...       ...      ...  ...       ...      ...
# 2667637   5337339   8013252.0  172193.0  75037.0   Y3   Surgery   Office
# 2668465    619540   1325703.0  172193.0  72351.0   Y3   Surgery   Office
# 2668560  74430325   8013252.0  172193.0  80381.0   Y1   Surgery   Office
# 2668755   5347417   2410265.0  172193.0  20893.0   Y2   Surgery   Office
# 2668756  91866140   6026848.0  172193.0  77134.0   Y3   Surgery   Office
#
#         PayDelay LengthOfStay         DSFS PrimaryConditionGroup  \
# 0             28          NaN  8- 9 months               NEUMENT
# 1464        162+          NaN  8- 9 months               NEUMENT
# 2422          97          NaN   0- 1 month                MSC2a3
# 3400          36          NaN  7- 8 months               NEUMENT
# 3962          36          NaN  5- 6 months               NEUMENT
# ...          ...          ...          ...                   ...
# 2667637        0          NaN  9-10 months               NEUMENT
# 2668465       29          NaN  1- 2 months               NEUMENT
# 2668560       28          NaN  7- 8 months               NEUMENT
# 2668755       29          NaN   0- 1 month               NEUMENT
# 2668756       30          NaN   0- 1 month               NEUMENT
#
#         CharlsonIndex ProcedureGroup  SupLOS
# 0                   0            MED       0
# 1464              1-2             EM       0
# 2422              1-2            MED       0
# 3400                0             EM       0
# 3962                0            MED       0
# ...               ...            ...     ...
# 2667637           1-2            MED       0
# 2668465           1-2            MED       0
# 2668560           1-2            MED       0
# 2668755             0           SEOA       0
# 2668756           1-2            MED       0
#
# [5958 rows x 14 columns]

# %%
len(claims_df["Vendor"].unique())
# Out:
# 6388

# %%
len(claims_df.loc[claims_df["ProviderID"] == 8013252.0])
# Out:
# 1803

# %%
claims_df.loc[(claims_df["ProviderID"] == 8013252.0) & (claims_df["Specialty"] != "Surgery")]
# Out:
#          MemberID  ProviderID    Vendor      PCP Year Specialty PlaceSvc  \
# 26573     8413237   8013252.0  172193.0  13281.0   Y1     Other   Office
# 45593    64280446   8013252.0  172193.0  65210.0   Y1     Other   Office
# 123522   31660692   8013252.0  172193.0  86510.0   Y1     Other   Office
# 153963   38468498   8013252.0  172193.0  29857.0   Y1     Other   Office
# 155189   42286978   8013252.0  172193.0  37796.0   Y1     Other   Office
# 231154   51470404   8013252.0  172193.0  39372.0   Y1     Other   Office
# 343631   52427296   8013252.0  172193.0  44164.0   Y1     Other   Office
# 359613    8413237   8013252.0  172193.0  13281.0   Y1     Other   Office
# 394235   41821681   8013252.0  172193.0  91279.0   Y1     Other   Office
# 504426   48672761   8013252.0  172193.0  89127.0   Y1     Other   Office
# 599356   63186834   8013252.0  172193.0  75037.0   Y1     Other   Office
# 669433   98265452   8013252.0  172193.0  77134.0   Y1     Other   Office
# 682776   92683483   8013252.0  172193.0  23056.0   Y1     Other   Office
# 804946   39055531   8013252.0  172193.0  86510.0   Y1     Other   Office
# 817285   28808907   8013252.0  172193.0  21579.0   Y1     Other   Office
# 928396   14014138   8013252.0  172193.0  88661.0   Y1     Other   Office
# 937810   94787198   8013252.0  172193.0  68968.0   Y1     Other   Office
# 1010951  41821681   8013252.0  172193.0  91279.0   Y1     Other   Office
# 1077915  20379730   8013252.0  172193.0  75037.0   Y1     Other   Office
# 1112739  92683483   8013252.0  172193.0  23056.0   Y1     Other   Office
# 1118516  98265452   8013252.0  172193.0  77134.0   Y1       NaN   Office
# 1245762  85172181   8013252.0  172193.0  93075.0   Y1     Other   Office
# 1294600   6666739   8013252.0  172193.0  18175.0   Y1     Other   Office
# 1498287  63186834   8013252.0  172193.0  75037.0   Y1     Other   Office
# 1584744  14014138   8013252.0  172193.0  88661.0   Y1     Other   Office
# 1698617  64858309   8013252.0  172193.0  21146.0   Y1     Other   Office
# 1736401  83708065   8013252.0  172193.0  13281.0   Y1     Other   Office
# 1740158  42255171   8013252.0  172193.0  77134.0   Y1     Other   Office
# 1899626  83934093   8013252.0  172193.0  80738.0   Y1       NaN   Office
# 1927974  11876692   8013252.0  172193.0  71255.0   Y1     Other   Office
# 1951110  73325501   8013252.0  172193.0  20893.0   Y1     Other   Office
# 1996272   8413237   8013252.0  172193.0  13281.0   Y1     Other   Office
# 2029136  92089069   8013252.0  172193.0  68968.0   Y1     Other   Office
# 2047798  51470404   8013252.0  172193.0  39372.0   Y1     Other   Office
# 2100898  22785657   8013252.0  172193.0  25395.0   Y1     Other   Office
# 2198384  35090117   8013252.0  172193.0  22193.0   Y1     Other   Office
# 2201359  14014138   8013252.0  172193.0  88661.0   Y1     Other   Office
# 2270183   8413237   8013252.0  172193.0  13281.0   Y1     Other   Office
# 2386753  39418955   8013252.0  172193.0  22193.0   Y1     Other   Office
# 2456011  63186834   8013252.0  172193.0  75037.0   Y1     Other   Office
# 2559599  22785657   8013252.0  172193.0  25395.0   Y1       NaN   Office
# 2625277  64858309   8013252.0  172193.0  21146.0   Y1     Other   Office
#
#         PayDelay LengthOfStay        DSFS PrimaryConditionGroup CharlsonIndex  \
# 26573         43          NaN  0- 1 month               NEUMENT             0
# 45593         15          NaN  0- 1 month               NEUMENT             0
# 123522        21          NaN  0- 1 month               NEUMENT             0
# 153963        44          NaN  0- 1 month               NEUMENT             0
# 155189        27          NaN  0- 1 month               NEUMENT             0
# 231154        30          NaN  0- 1 month               NEUMENT           1-2
# 343631        34          NaN  0- 1 month               NEUMENT             0
# 359613        36          NaN  0- 1 month               NEUMENT             0
# 394235        30          NaN  0- 1 month               NEUMENT             0
# 504426        41          NaN  0- 1 month               NEUMENT           1-2
# 599356        41          NaN  0- 1 month               NEUMENT             0
# 669433        34          NaN  0- 1 month               NEUMENT           1-2
# 682776        34          NaN  0- 1 month               NEUMENT             0
# 804946        36          NaN  0- 1 month               NEUMENT           1-2
# 817285        36          NaN  0- 1 month               NEUMENT             0
# 928396        44          NaN  0- 1 month               NEUMENT             0
# 937810        35          NaN  0- 1 month               NEUMENT             0
# 1010951       30          NaN  0- 1 month               NEUMENT             0
# 1077915       34          NaN  0- 1 month               NEUMENT             0
# 1112739       37          NaN  0- 1 month               NEUMENT             0
# 1118516       34          NaN  0- 1 month               NEUMENT           1-2
# 1245762       34          NaN  0- 1 month               NEUMENT             0
# 1294600       38          NaN  0- 1 month               NEUMENT             0
# 1498287       41          NaN  0- 1 month               NEUMENT             0
# 1584744       20          NaN  0- 1 month               NEUMENT             0
# 1698617       36          NaN  0- 1 month               NEUMENT             0
# 1736401       31          NaN  0- 1 month               NEUMENT             0
# 1740158       44          NaN  0- 1 month               NEUMENT             0
# 1899626       34          NaN  0- 1 month               NEUMENT             0
# 1927974       38          NaN  0- 1 month               NEUMENT             0
# 1951110       36          NaN  0- 1 month               NEUMENT             0
# 1996272       36          NaN  0- 1 month               NEUMENT             0
# 2029136       31          NaN  0- 1 month               NEUMENT           3-4
# 2047798       30          NaN  0- 1 month               NEUMENT           1-2
# 2100898       34          NaN  0- 1 month               NEUMENT             0
# 2198384       31          NaN  0- 1 month               NEUMENT             0
# 2201359       20          NaN  0- 1 month               NEUMENT             0
# 2270183       43          NaN  0- 1 month               NEUMENT             0
# 2386753       30          NaN  0- 1 month               NEUMENT             0
# 2456011       36          NaN  0- 1 month               NEUMENT             0
# 2559599       34          NaN  0- 1 month               NEUMENT             0
# 2625277       36          NaN  0- 1 month               NEUMENT             0
#
#         ProcedureGroup  SupLOS
# 26573               EM       0
# 45593              MED       0
# 123522              EM       0
# 153963             MED       0
# 155189             MED       0
# 231154              EM       0
# 343631             MED       0
# 359613              EM       0
# 394235              EM       0
# 504426             MED       0
# 599356              EM       0
# 669433              EM       0
# 682776              EM       0
# 804946              EM       0
# 817285             MED       0
# 928396            SEOA       0
# 937810             MED       0
# 1010951            MED       0
# 1077915             EM       0
# 1112739            MED       0
# 1118516           SEOA       0
# 1245762            MED       0
# 1294600            MED       0
# 1498287            MED       0
# 1584744             EM       0
# 1698617             EM       0
# 1736401            MED       0
# 1740158            MED       0
# 1899626           SEOA       0
# 1927974             EM       0
# 1951110            MED       0
# 1996272            MED       0
# 2029136             EM       0
# 2047798            MED       0
# 2100898             EM       0
# 2198384             EM       0
# 2201359            MED       0
# 2270183            MED       0
# 2386753            MED       0
# 2456011            MED       0
# 2559599            RAD       0
# 2625277            MED       0

# %%
len(claims_df.loc[(claims_df["ProviderID"] == 8013252.0) & (claims_df["Specialty"] == "Surgery")])
# Out:
# 1761

# %%
claims_Y1 = claims_df.loc[claims_df["Year"] == "Y1"]
claims_Y2 = claims_df.loc[claims_df["Year"] == "Y2"]
claims_Y3 = claims_df.loc[claims_df["Year"] == "Y3"]

# %%
claims_Y1["Year"].unique()
# Out:
# array(['Y1'], dtype=object)

# %%
claims_df["LengthOfStay"].unique()
# Out:
# array([nan, '1 day', '2- 4 weeks', '2 days', '3 days', '4 days',
#        '1- 2 weeks', '4- 8 weeks', '6 days', '5 days', '26+ weeks'],
#       dtype=object)

# %%
days_in_hospital_y2_df.head()
# Out:
#    MemberID  ClaimsTruncated  DaysInHospital
# 0  24027423                0               0
# 1  98324177                0               0
# 2  33899367                1               1
# 3   5481382                0               1
# 4  69908334                0               0

# %%
days_in_hospital_y3_df.head()
# Out:
#    MemberID  ClaimsTruncated  DaysInHospital
# 0  90963501                0               0
# 1  85160905                0               0
# 2  45496648                0               0
# 3  45162557                0               0
# 4  68793937                0               0

# %%
drug_count_df.head()
# Out:
#    MemberID Year          DSFS DrugCount
# 0  48925661   Y2   9-10 months        7+
# 1  90764620   Y3   8- 9 months         3
# 2  61221204   Y1   2- 3 months         1
# 3  63628544   Y3   1- 2 months         1
# 4  46949606   Y2  10-11 months         3

# %%
lab_count_df.head()
# Out:
#    MemberID Year         DSFS LabCount
# 0  69258001   Y3  2- 3 months        1
# 1  10143167   Y1   0- 1 month        2
# 2   1054357   Y1   0- 1 month        6
# 3  56583841   Y3  6- 7 months        4
# 4  70967047   Y2   0- 1 month        2

# %%
lookup_primary_condition_group_df.head()
# Out:
#   PrimaryConditionGroup                  Description
# 0                   AMI  Acute myocardial infarction
# 1               APPCHOL                 Appendicitis
# 2              ARTHSPIN                Arthropathies
# 3                CANCRA                     Cancer A
# 4                CANCRB                     Cancer B

# %%
lookup_procedure_group_df.head()
# Out:
#   ProcedureGroup                Description
# 0           ANES                 Anesthesia
# 1             EM  Evaluation and Management
# 2            MED                   Medicine
# 3             PL   Pathology and Laboratory
# 4            RAD                  Radiology

# %%
members_df.head()
# Out:
#    MemberID AgeAtFirstClaim Sex
# 0  14723353           70-79   M
# 1  75706636           70-79   M
# 2  17320609           70-79   M
# 3  69690888           40-49   M
# 4  33004608             0-9   M

# %%
target_df.head()
# Out:
#    MemberID  ClaimsTruncated  DaysInHospital
# 0  20820036                0             NaN
# 1  14625274                1             NaN
# 2  99227820                0             NaN
# 3  74486714                0             NaN
# 4  92341995                0             NaN

# %%
claims_df.head()
# Out:
#    MemberID  ProviderID    Vendor      PCP Year   Specialty  \
# 0  42286978   8013252.0  172193.0  37796.0   Y1     Surgery
# 1  97903248   3316066.0  726296.0   5300.0   Y3    Internal
# 2   2759427   2997752.0  140343.0  91972.0   Y3    Internal
# 3  73570559   7053364.0  240043.0  70119.0   Y3  Laboratory
# 4  11837054   7557061.0  496247.0  68968.0   Y2     Surgery
#
#               PlaceSvc PayDelay LengthOfStay         DSFS  \
# 0               Office       28          NaN  8- 9 months
# 1               Office       50          NaN  7- 8 months
# 2               Office       14          NaN   0- 1 month
# 3      Independent Lab       24          NaN  5- 6 months
# 4  Outpatient Hospital       27          NaN  4- 5 months
#
#   PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 0               NEUMENT             0            MED       0
# 1               NEUMENT           1-2             EM       0
# 2                METAB3             0             EM       0
# 3                METAB3           1-2            SCS       0
# 4               FXDISLC           1-2             EM       0

# %%
trial_df = claims_df[claims_df["MemberID"] == 42286978]

# %%
trial_df
# Out:
#          MemberID  ProviderID    Vendor      PCP Year         Specialty  \
# 0        42286978   8013252.0  172193.0  37796.0   Y1           Surgery
# 76157    42286978   9416979.0    5166.0  37796.0   Y1          Internal
# 105192   42286978   8511459.0   64764.0  37796.0   Y1          Internal
# 155189   42286978   8013252.0  172193.0  37796.0   Y1             Other
# 424786   42286978   9416979.0    5166.0  37796.0   Y1          Internal
# 515791   42286978   4062524.0  505451.0  37796.0   Y1          Internal
# 635729   42286978   3022514.0   35565.0  37796.0   Y1               NaN
# 738941   42286978   7053364.0  240043.0  37796.0   Y1        Laboratory
# 1158231  42286978   7053364.0  240043.0  37796.0   Y1        Laboratory
# 2286859  42286978   7557061.0  496247.0  37796.0   Y1           Surgery
# 2303524  42286978    438280.0  122401.0  37796.0   Y1  General Practice
# 2590363  42286978   8013252.0  172193.0  37796.0   Y1           Surgery
#
#                     PlaceSvc PayDelay LengthOfStay          DSFS  \
# 0                     Office       28          NaN   8- 9 months
# 76157                 Office       58          NaN   9-10 months
# 105192                Office       92          NaN    0- 1 month
# 155189                Office       27          NaN    0- 1 month
# 424786                Office      114          NaN   6- 7 months
# 515791   Outpatient Hospital       34          NaN   1- 2 months
# 635729                Office       28          NaN   7- 8 months
# 738941       Independent Lab       32          NaN   9-10 months
# 1158231      Independent Lab       32          NaN   9-10 months
# 2286859               Office       62          NaN   1- 2 months
# 2303524               Office       58          NaN  10-11 months
# 2590363               Office       28          NaN   8- 9 months
#
#         PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 0                     NEUMENT             0            MED       0
# 76157                 MISCHRT             0             EM       0
# 105192                 SKNAUT             0             EM       0
# 155189                NEUMENT             0            MED       0
# 424786                GIBLEED             0             EM       0
# 515791                 MSC2a3             0             EM       0
# 635729                ODaBNCA             0            RAD       0
# 738941                 METAB3             0            SCS       0
# 1158231                METAB3             0             PL       0
# 2286859              ARTHSPIN             0             EM       0
# 2303524                MSC2a3             0            MED       0
# 2590363               NEUMENT             0             EM       0

# %%
trial_df.shape
# Out:
# (12, 14)

# %%
days_in_hospital_y2_df.loc[days_in_hospital_y2_df["MemberID"] == 42286978]
# Out:
#        MemberID  ClaimsTruncated  DaysInHospital
# 55848  42286978                0               2

# %%
days_in_hospital_y3_df.loc[days_in_hospital_y3_df["MemberID"] == 42286978]
# Out:
# Empty DataFrame
# Columns: [MemberID, ClaimsTruncated, DaysInHospital]
# Index: []

# %%
claims_df["LengthOfStay"].fillna(0, inplace=True)

# %%
claims_df
# Out:
#          MemberID  ProviderID    Vendor      PCP Year  \
# 0        42286978   8013252.0  172193.0  37796.0   Y1
# 1        97903248   3316066.0  726296.0   5300.0   Y3
# 2         2759427   2997752.0  140343.0  91972.0   Y3
# 3        73570559   7053364.0  240043.0  70119.0   Y3
# 4        11837054   7557061.0  496247.0  68968.0   Y2
# ...           ...         ...       ...      ...  ...
# 2668985  14932948   6641119.0  693028.0  22193.0   Y2
# 2668986  31248189   6932712.0  223304.0  70748.0   Y3
# 2668987  43767339   1483429.0   35565.0   5278.0   Y3
# 2668988  96393713   7094351.0  347045.0  93075.0   Y3
# 2668989  57805129   3884005.0  523319.0  90756.0   Y1
#
#                          Specialty             PlaceSvc PayDelay LengthOfStay  \
# 0                          Surgery               Office       28            0
# 1                         Internal               Office       50            0
# 2                         Internal               Office       14            0
# 3                       Laboratory      Independent Lab       24            0
# 4                          Surgery  Outpatient Hospital       27            0
# ...                            ...                  ...      ...          ...
# 2668985  Obstetrics and Gynecology   Inpatient Hospital       58            0
# 2668986                   Internal   Inpatient Hospital       23            0
# 2668987         Diagnostic Imaging               Office      122            0
# 2668988                   Internal               Office      151            0
# 2668989                   Internal               Office       15            0
#
#                 DSFS PrimaryConditionGroup CharlsonIndex ProcedureGroup  \
# 0        8- 9 months               NEUMENT             0            MED
# 1        7- 8 months               NEUMENT           1-2             EM
# 2         0- 1 month                METAB3             0             EM
# 3        5- 6 months                METAB3           1-2            SCS
# 4        4- 5 months               FXDISLC           1-2             EM
# ...              ...                   ...           ...            ...
# 2668985   0- 1 month                GYNEC1             0             EM
# 2668986   0- 1 month               GIBLEED           1-2             EM
# 2668987  4- 5 months               ODaBNCA             0            SIS
# 2668988  1- 2 months                METAB3           1-2             EM
# 2668989  4- 5 months                SKNAUT           1-2             EM
#
#          SupLOS
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2668985       0
# 2668986       0
# 2668987       0
# 2668988       0
# 2668989       0
#
# [2668990 rows x 14 columns]

# %%
len(target_df["MemberID"].unique())
# Out:
# 70942

# %%
len(claims_Y3["MemberID"].unique())
# Out:
# 70942

# %%
len(claims_Y2["MemberID"].unique())
# Out:
# 71435

# %%
len(days_in_hospital_y3_df["MemberID"].unique())
# Out:
# 71435

# %%
days_in_hospital_y2_df["DaysInHospital"].unique()
# Out:
# array([ 0,  1,  4,  6,  5,  2, 15,  3,  8,  7,  9, 12, 10, 13, 14, 11])

# %%
len(members_df["MemberID"].unique())
# Out:
# 113000

# %%
members_df.head()
# Out:
#    MemberID AgeAtFirstClaim Sex
# 0  14723353           70-79   M
# 1  75706636           70-79   M
# 2  17320609           70-79   M
# 3  69690888           40-49   M
# 4  33004608             0-9   M

# %%
claims_df
# Out:
#          MemberID  ProviderID    Vendor      PCP Year  \
# 0        42286978   8013252.0  172193.0  37796.0   Y1
# 1        97903248   3316066.0  726296.0   5300.0   Y3
# 2         2759427   2997752.0  140343.0  91972.0   Y3
# 3        73570559   7053364.0  240043.0  70119.0   Y3
# 4        11837054   7557061.0  496247.0  68968.0   Y2
# ...           ...         ...       ...      ...  ...
# 2668985  14932948   6641119.0  693028.0  22193.0   Y2
# 2668986  31248189   6932712.0  223304.0  70748.0   Y3
# 2668987  43767339   1483429.0   35565.0   5278.0   Y3
# 2668988  96393713   7094351.0  347045.0  93075.0   Y3
# 2668989  57805129   3884005.0  523319.0  90756.0   Y1
#
#                          Specialty             PlaceSvc PayDelay LengthOfStay  \
# 0                          Surgery               Office       28          NaN
# 1                         Internal               Office       50          NaN
# 2                         Internal               Office       14          NaN
# 3                       Laboratory      Independent Lab       24          NaN
# 4                          Surgery  Outpatient Hospital       27          NaN
# ...                            ...                  ...      ...          ...
# 2668985  Obstetrics and Gynecology   Inpatient Hospital       58          NaN
# 2668986                   Internal   Inpatient Hospital       23          NaN
# 2668987         Diagnostic Imaging               Office      122          NaN
# 2668988                   Internal               Office      151          NaN
# 2668989                   Internal               Office       15          NaN
#
#                 DSFS PrimaryConditionGroup CharlsonIndex ProcedureGroup  \
# 0        8- 9 months               NEUMENT             0            MED
# 1        7- 8 months               NEUMENT           1-2             EM
# 2         0- 1 month                METAB3             0             EM
# 3        5- 6 months                METAB3           1-2            SCS
# 4        4- 5 months               FXDISLC           1-2             EM
# ...              ...                   ...           ...            ...
# 2668985   0- 1 month                GYNEC1             0             EM
# 2668986   0- 1 month               GIBLEED           1-2             EM
# 2668987  4- 5 months               ODaBNCA             0            SIS
# 2668988  1- 2 months                METAB3           1-2             EM
# 2668989  4- 5 months                SKNAUT           1-2             EM
#
#          SupLOS
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2668985       0
# 2668986       0
# 2668987       0
# 2668988       0
# 2668989       0
#
# [2668990 rows x 14 columns]

# %%
claims_Y1[claims_Y1["MemberID"] == 42286978]
# Out:
#          MemberID  ProviderID    Vendor      PCP Year         Specialty  \
# 0        42286978   8013252.0  172193.0  37796.0   Y1           Surgery
# 76157    42286978   9416979.0    5166.0  37796.0   Y1          Internal
# 105192   42286978   8511459.0   64764.0  37796.0   Y1          Internal
# 155189   42286978   8013252.0  172193.0  37796.0   Y1             Other
# 424786   42286978   9416979.0    5166.0  37796.0   Y1          Internal
# 515791   42286978   4062524.0  505451.0  37796.0   Y1          Internal
# 635729   42286978   3022514.0   35565.0  37796.0   Y1               NaN
# 738941   42286978   7053364.0  240043.0  37796.0   Y1        Laboratory
# 1158231  42286978   7053364.0  240043.0  37796.0   Y1        Laboratory
# 2286859  42286978   7557061.0  496247.0  37796.0   Y1           Surgery
# 2303524  42286978    438280.0  122401.0  37796.0   Y1  General Practice
# 2590363  42286978   8013252.0  172193.0  37796.0   Y1           Surgery
#
#                     PlaceSvc PayDelay LengthOfStay          DSFS  \
# 0                     Office       28            0   8- 9 months
# 76157                 Office       58            0   9-10 months
# 105192                Office       92            0    0- 1 month
# 155189                Office       27            0    0- 1 month
# 424786                Office      114            0   6- 7 months
# 515791   Outpatient Hospital       34            0   1- 2 months
# 635729                Office       28            0   7- 8 months
# 738941       Independent Lab       32            0   9-10 months
# 1158231      Independent Lab       32            0   9-10 months
# 2286859               Office       62            0   1- 2 months
# 2303524               Office       58            0  10-11 months
# 2590363               Office       28            0   8- 9 months
#
#         PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 0                     NEUMENT             0            MED       0
# 76157                 MISCHRT             0             EM       0
# 105192                 SKNAUT             0             EM       0
# 155189                NEUMENT             0            MED       0
# 424786                GIBLEED             0             EM       0
# 515791                 MSC2a3             0             EM       0
# 635729                ODaBNCA             0            RAD       0
# 738941                 METAB3             0            SCS       0
# 1158231                METAB3             0             PL       0
# 2286859              ARTHSPIN             0             EM       0
# 2303524                MSC2a3             0            MED       0
# 2590363               NEUMENT             0             EM       0

# %%
days_in_hospital_y2_df.loc[days_in_hospital_y2_df["MemberID"] == 42286978]
# Out:
#        MemberID  ClaimsTruncated  DaysInHospital
# 55848  42286978                0               2

# %%
days_in_hospital_y3_df.loc[days_in_hospital_y3_df["MemberID"] == 42286978]
# Out:
# Empty DataFrame
# Columns: [MemberID, ClaimsTruncated, DaysInHospital]
# Index: []

# %%
drug_count_df.loc[drug_count_df["MemberID"] == 42286978]
# Out:
#         MemberID Year          DSFS DrugCount
# 3688    42286978   Y1   8- 9 months         3
# 5680    42286978   Y1   4- 5 months         5
# 8460    42286978   Y1   5- 6 months         2
# 90863   42286978   Y1  11-12 months         1
# 159933  42286978   Y1   1- 2 months         2
# 179757  42286978   Y1   7- 8 months         4
# 272584  42286978   Y1  10-11 months         5
# 357051  42286978   Y1    0- 1 month         1
# 490417  42286978   Y1   6- 7 months         1
# 561775  42286978   Y1   2- 3 months         2

# %%
lab_count_df.loc[lab_count_df["MemberID"] == 42286978]
# Out:
#         MemberID Year         DSFS LabCount
# 161775  42286978   Y1  9-10 months        8

# %%
claims_df[claims_df["DSFS"].isnull()]
# Out:
#          MemberID  ProviderID    Vendor      PCP Year       Specialty  \
# 10       12333431    605446.0  120581.0  20893.0   Y3  Anesthesiology
# 70        1104236   9131180.0  140343.0  87960.0   Y1         Surgery
# 163      95487644   6251259.0       NaN  57560.0   Y3       Emergency
# 379      19931416   5768423.0  213218.0  20893.0   Y3       Pathology
# 398      30614666         NaN       NaN      NaN   Y3             NaN
# ...           ...         ...       ...      ...  ...             ...
# 2668848  16668717   3116609.0  852570.0  91972.0   Y2        Internal
# 2668885  27468733    542160.0  688026.0  91972.0   Y1  Anesthesiology
# 2668959  65580539   4580430.0  150649.0  13281.0   Y2         Surgery
# 2668970  14098507   7512468.0  122401.0  18880.0   Y2         Surgery
# 2668975   1344508   4107701.0  164823.0  78718.0   Y1      Laboratory
#
#                     PlaceSvc PayDelay LengthOfStay DSFS PrimaryConditionGroup  \
# 10       Outpatient Hospital       37          NaN  NaN              ARTHSPIN
# 70                    Office       65          NaN  NaN                MISCL5
# 163                      NaN       23          NaN  NaN                GYNECA
# 379       Inpatient Hospital        0          NaN  NaN               ODaBNCA
# 398                    Other        0          NaN  NaN                RESPR4
# ...                      ...      ...          ...  ...                   ...
# 2668848  Outpatient Hospital     162+        1 day  NaN                MSC2a3
# 2668885            Ambulance       43          NaN  NaN                TRAUMA
# 2668959   Inpatient Hospital       38          NaN  NaN                CANCRB
# 2668970               Office       31          NaN  NaN                SKNAUT
# 2668975      Independent Lab       17          NaN  NaN                CATAST
#
#         CharlsonIndex ProcedureGroup  SupLOS
# 10                1-2           ANES       0
# 70                  0             EM       0
# 163               3-4             EM       0
# 379                 0             PL       0
# 398               1-2            RAD       0
# ...               ...            ...     ...
# 2668848             0            SUS       0
# 2668885             0           ANES       0
# 2668959           1-2            SUS       0
# 2668970             0             EM       0
# 2668975             0            SCS       0
#
# [52770 rows x 14 columns]

# %%
claims_df[(claims_df["MemberID"] == 1104236) & (claims_df["Year"] == "Y1")]
# Out:
#          MemberID  ProviderID    Vendor      PCP Year         Specialty  \
# 70        1104236   9131180.0  140343.0  87960.0   Y1           Surgery
# 172731    1104236   5738349.0   85427.0  87960.0   Y1  General Practice
# 284353    1104236   1076052.0  251809.0  87960.0   Y1        Laboratory
# 328999    1104236   1076052.0  251809.0  87960.0   Y1        Laboratory
# 515673    1104236   4542549.0  728319.0  87960.0   Y1    Anesthesiology
# 632959    1104236   1076052.0  251809.0  87960.0   Y1        Laboratory
# 649643    1104236   9131180.0  140343.0  87960.0   Y1           Surgery
# 658739    1104236   1396952.0  761670.0  87960.0   Y1           Surgery
# 698526    1104236   9131180.0  140343.0  87960.0   Y1           Surgery
# 749246    1104236   3572884.0  140343.0  87960.0   Y1         Emergency
# 911625    1104236   1076052.0  251809.0  87960.0   Y1        Laboratory
# 1111013   1104236   1076052.0  251809.0  87960.0   Y1        Laboratory
# 1205741   1104236   9131180.0  140343.0  87960.0   Y1           Surgery
# 1402579   1104236   3572884.0  140343.0  87960.0   Y1         Emergency
# 1697071   1104236   9131180.0  140343.0  87960.0   Y1           Surgery
# 2286181   1104236   5738349.0   85427.0  87960.0   Y1  General Practice
# 2435917   1104236   9131180.0  140343.0  87960.0   Y1           Surgery
# 2609133   1104236   9131180.0  140343.0  87960.0   Y1           Surgery
#
#                 PlaceSvc PayDelay LengthOfStay          DSFS  \
# 70                Office       65          NaN           NaN
# 172731            Office       17          NaN    0- 1 month
# 284353   Independent Lab       32          NaN  11-12 months
# 328999   Independent Lab       34          NaN  11-12 months
# 515673         Ambulance       53          NaN           NaN
# 632959   Independent Lab       52          NaN   7- 8 months
# 649643            Office       74          NaN           NaN
# 658739         Ambulance       32          NaN           NaN
# 698526            Office       73          NaN           NaN
# 749246       Urgent Care       85          NaN   5- 6 months
# 911625   Independent Lab       34          NaN  11-12 months
# 1111013  Independent Lab       52          NaN   7- 8 months
# 1205741           Office       63          NaN           NaN
# 1402579      Urgent Care       85          NaN   5- 6 months
# 1697071           Office     162+          NaN  11-12 months
# 2286181           Office       31          NaN   7- 8 months
# 2435917           Office       72          NaN           NaN
# 2609133           Office       71          NaN           NaN
#
#         PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 70                     MISCL5             0             EM       0
# 172731                 MSC2a3             0            MED       0
# 284353                 MISCL5             0             PL       0
# 328999                 MSC2a3             0             PL       0
# 515673                 MISCL5             0           ANES       0
# 632959                 MSC2a3             0             PL       0
# 649643                 MISCL5             0             EM       0
# 658739                    NaN             0            SDS       1
# 698526                 INFEC4             0            MED       0
# 749246                 RESPR4             0             PL       0
# 911625                 MSC2a3             0            SCS       0
# 1111013                MSC2a3             0            SCS       0
# 1205741                INFEC4             0             EM       0
# 1402579                RESPR4             0             EM       0
# 1697071                TRAUMA             0             EM       0
# 2286181                MSC2a3             0             EM       0
# 2435917                INFEC4             0            MED       0
# 2609133                INFEC4             0            MED       0

# %%
claims_df.isnull()
# Out:
#          MemberID  ProviderID  Vendor    PCP   Year  Specialty  PlaceSvc  \
# 0           False       False   False  False  False      False     False
# 1           False       False   False  False  False      False     False
# 2           False       False   False  False  False      False     False
# 3           False       False   False  False  False      False     False
# 4           False       False   False  False  False      False     False
# ...           ...         ...     ...    ...    ...        ...       ...
# 2668985     False       False   False  False  False      False     False
# 2668986     False       False   False  False  False      False     False
# 2668987     False       False   False  False  False      False     False
# 2668988     False       False   False  False  False      False     False
# 2668989     False       False   False  False  False      False     False
#
#          PayDelay  LengthOfStay   DSFS  PrimaryConditionGroup  CharlsonIndex  \
# 0           False          True  False                  False          False
# 1           False          True  False                  False          False
# 2           False          True  False                  False          False
# 3           False          True  False                  False          False
# 4           False          True  False                  False          False
# ...           ...           ...    ...                    ...            ...
# 2668985     False          True  False                  False          False
# 2668986     False          True  False                  False          False
# 2668987     False          True  False                  False          False
# 2668988     False          True  False                  False          False
# 2668989     False          True  False                  False          False
#
#          ProcedureGroup  SupLOS
# 0                 False   False
# 1                 False   False
# 2                 False   False
# 3                 False   False
# 4                 False   False
# ...                 ...     ...
# 2668985           False   False
# 2668986           False   False
# 2668987           False   False
# 2668988           False   False
# 2668989           False   False
#
# [2668990 rows x 14 columns]

# %%
claims_Y1.to_csv("../data/raw/HHP_release3/Claims_Y1.csv")

# %%
claims_Y1.shape
# Out:
# (865689, 14)

# %%
claims_Y2.shape
# Out:
# (898872, 14)

# %%
claims_Y1.head()
# Out:
#     MemberID  ProviderID    Vendor      PCP Year           Specialty  \
# 0   42286978   8013252.0  172193.0  37796.0   Y1             Surgery
# 6   99829076   6721023.0  265273.0  91972.0   Y1      Rehabilitation
# 7   54666321   9932074.0   35565.0  27294.0   Y1  Diagnostic Imaging
# 11  66951188   4699470.0  179509.0  75876.0   Y1  Diagnostic Imaging
# 12  78859054   9121540.0  523791.0  21579.0   Y1           Emergency
#
#               PlaceSvc PayDelay LengthOfStay         DSFS  \
# 0               Office       28          NaN  8- 9 months
# 6               Office     162+          NaN   0- 1 month
# 7               Office       29          NaN   0- 1 month
# 11  Inpatient Hospital       51          NaN   0- 1 month
# 12         Urgent Care       22        1 day  6- 7 months
#
#    PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 0                NEUMENT             0            MED       0
# 6                 TRAUMA             0            MED       0
# 7                 RESPR4             0            RAD       0
# 11                 ROAMI             0            RAD       0
# 12                HEART2             0            SDS       0

# %%
claims_df[claims_df["MemberID"] == 45847458]
# Out:
#          MemberID  ProviderID    Vendor      PCP Year           Specialty  \
# 198      45847458         NaN       NaN  32724.0   Y2            Internal
# 13810    45847458   8917695.0  576236.0  32724.0   Y3      Anesthesiology
# 78396    45847458   8986088.0  223304.0  32724.0   Y2            Internal
# 139870   45847458   2698620.0  866910.0  32724.0   Y3            Internal
# 223737   45847458   6290049.0  865096.0  32724.0   Y2            Internal
# ...           ...         ...       ...      ...  ...                 ...
# 2539388  45847458   4107701.0  164823.0  32724.0   Y3          Laboratory
# 2576660  45847458   9585773.0  425431.0  32724.0   Y2  Diagnostic Imaging
# 2637265  45847458   4107701.0  164823.0  32724.0   Y2          Laboratory
# 2660615  45847458   6251259.0  791272.0  32724.0   Y3            Internal
# 2661150  45847458   6164824.0  791272.0  32724.0   Y3            Internal
#
#                     PlaceSvc PayDelay LengthOfStay         DSFS  \
# 198      Outpatient Hospital       19          NaN  1- 2 months
# 13810    Outpatient Hospital       24          NaN          NaN
# 78396              Ambulance       23          NaN  3- 4 months
# 139870                Office       41          NaN  4- 5 months
# 223737                Office       20          NaN  6- 7 months
# ...                      ...      ...          ...          ...
# 2539388      Independent Lab       14          NaN  2- 3 months
# 2576660               Office       21          NaN  4- 5 months
# 2637265      Independent Lab       30          NaN   0- 1 month
# 2660615               Office       97          NaN  3- 4 months
# 2661150               Office     162+          NaN  4- 5 months
#
#         PrimaryConditionGroup CharlsonIndex ProcedureGroup  SupLOS
# 198                  ARTHSPIN             0           ANES       1
# 13810                  CANCRB           1-2           ANES       0
# 78396                 ODaBNCA             0            SDS       0
# 139870                 SKNAUT           1-2             EM       0
# 223737               ARTHSPIN           1-2             EM       0
# ...                       ...           ...            ...     ...
# 2539388                MSC2a3           1-2             PL       0
# 2576660              ARTHSPIN           1-2            RAD       0
# 2637265                METAB3             0             PL       0
# 2660615              ARTHSPIN           1-2             EM       0
# 2661150                MSC2a3           1-2            RAD       0
#
# [81 rows x 14 columns]

# %%
claims_df[claims_df["ProviderID"].isna()]
# Out:
#          MemberID  ProviderID  Vendor      PCP Year  \
# 198      45847458         NaN     NaN  32724.0   Y2
# 398      30614666         NaN     NaN      NaN   Y3
# 475      90054573         NaN     NaN  70853.0   Y1
# 709      85492358         NaN     NaN      NaN   Y3
# 1005     38061764         NaN     NaN  27467.0   Y1
# ...           ...         ...     ...      ...  ...
# 2668215  58586705         NaN     NaN      NaN   Y1
# 2668273   9896396         NaN     NaN  81146.0   Y1
# 2668513  76173344         NaN     NaN   5846.0   Y1
# 2668611  52536668         NaN     NaN      NaN   Y1
# 2668614   3294292         NaN     NaN      NaN   Y3
#
#                          Specialty             PlaceSvc PayDelay LengthOfStay  \
# 198                       Internal  Outpatient Hospital       19          NaN
# 398                            NaN                Other        0          NaN
# 475             Diagnostic Imaging               Office       17          NaN
# 709                            NaN               Office       34          NaN
# 1005                      Internal   Inpatient Hospital       53       3 days
# ...                            ...                  ...      ...          ...
# 2668215                      Other                  NaN       79          NaN
# 2668273                      Other  Outpatient Hospital       27          NaN
# 2668513                   Internal          Urgent Care       47          NaN
# 2668611  Obstetrics and Gynecology                  NaN       86          NaN
# 2668614                      Other                 Home       97          NaN
#
#                 DSFS PrimaryConditionGroup CharlsonIndex ProcedureGroup  \
# 198      1- 2 months              ARTHSPIN             0           ANES
# 398              NaN                RESPR4           1-2            RAD
# 475      4- 5 months               ODaBNCA           1-2             EM
# 709       0- 1 month               SEIZURE           1-2            SIS
# 1005      0- 1 month                STROKE           3-4            SCS
# ...              ...                   ...           ...            ...
# 2668215          NaN                HEART2           1-2            MED
# 2668273  2- 3 months                HEMTOL             0             PL
# 2668513          NaN                   NaN             0           ANES
# 2668611          NaN                INFEC4             0            SIS
# 2668614  1- 2 months                MISCL1             0            MED
#
#          SupLOS
# 198           1
# 398           0
# 475           0
# 709           0
# 1005          0
# ...         ...
# 2668215       0
# 2668273       0
# 2668513       1
# 2668611       0
# 2668614       0
#
# [16264 rows x 14 columns]

# %%
claims_df["PayDelay"].unique()
# Out:
# array(['28', '50', '14', '24', '27', '25', '162+', '29', '42', '56', '37',
#        '51', '22', '21', '143', '62', '46', '31', '34', '16', '23', '48',
#        '75', '17', '0', '84', '35', '41', '30', '148', '65', '45', '60',
#        '18', '49', '15', '93', '74', '66', '26', '135', '9', '20', '112',
#        '72', '36', '39', '63', '55', '53', '11', '88', '58', '136', '4',
#        '47', '155', '43', '7', '71', '13', '8', '115', '70', '44', '57',
#        '82', '59', '128', '103', '78', '3', '19', '80', '73', '32', '120',
#        '79', '10', '94', '86', '38', '106', '85', '111', '133', '76',
#        '122', '52', '127', '101', '67', '12', '81', '5', '92', '40',
#        '140', '69', '64', '87', '105', '116', '61', '123', '89', '109',
#        '134', '98', '114', '156', '68', '91', '90', '83', '126', '142',
#        '144', '154', '118', '107', '54', '130', '150', '33', '108', '100',
#        '99', '102', '161', '159', '97', '121', '95', '158', '77', '147',
#        '157', '153', '104', '113', '141', '132', '152', '125', '110',
#        '131', '145', '139', '137', '119', '129', '96', '117', '149', '6',
#        '124', '146', '138', '160', '151', '2', '1'], dtype=object)

# %%
claims_df["LengthOfStay"].unique()
# Out:
# array([nan, '1 day', '2- 4 weeks', '2 days', '3 days', '4 days',
#        '1- 2 weeks', '4- 8 weeks', '6 days', '5 days', '26+ weeks'],
#       dtype=object)

# %%
claims_df["CharlsonIndex"].unique()
# Out:
# array(['0', '1-2', '3-4', '5+'], dtype=object)

# %%
claims_df["SupLOS"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Group by 'MemberID' and calculate the mode for each required column
result = claims_Y1.groupby('MemberID').agg({
    'ProviderID': lambda x: x.mode()[0] if not x.mode().empty else None,
    'Vendor': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PCP': lambda x: x.mode()[0] if not x.mode().empty else None,
    'Specialty': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PlaceSvc': lambda x: x.mode()[0] if not x.mode().empty else None,
    'DSFS': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PrimaryConditionGroup': lambda x: x.mode()[0] if not x.mode().empty else None,
    'ProcedureGroup': lambda x: x.mode()[0] if not x.mode().empty else None,
    'SupLOS': lambda x: x.mode()[0] if not x.mode().empty else None
})

# Display the resulting dataframe
import ace_tools as tools; tools.display_dataframe_to_user(name="Most Common Values per MemberID", dataframe=result)

# %% [markdown]
# Preprocessing

# %%
# Define mapping for 'DSFS' conversion to numeric
dsfs_mapping = {
    '0- 1 month': 1,
    '1- 2 months': 2,
    '2- 3 months': 3,
    '3- 4 months': 4,
    '4- 5 months': 5,
    '5- 6 months': 6,
    '6- 7 months': 7,
    '7- 8 months': 8,
    '8- 9 months': 9,
    '9-10 months': 10,
    '10-11 months': 11,
    '11-12 months': 12
}

charlsonIndex_mapping = {
    '0': 0,
    '1-2': 2,
    '3-4': 3.5,
    '5+': 5
}

length_of_stay_mapping = {
    '1 day': 1,
    '2 days': 2,
    '3 days': 3,
    '4 days': 4,
    '5 days': 5,
    '6 days': 6,
    '1- 2 weeks': 10,  # Averaging 1.5 weeks (approximately 10 days)
    '2- 4 weeks': 21,  # Averaging 3 weeks (approximately 21 days)
    '4- 8 weeks': 42,  # Averaging 6 weeks (approximately 42 days)
    '26+ weeks': 182   # 26 weeks (approximately 182 days)
}

# Apply the mapping to the LengthOfStay column, replacing NaN with NaN
claims_df['LengthOfStay'] = claims_df['LengthOfStay'].map(length_of_stay_mapping)
claims_df["LengthOfStay"].fillna(0, inplace=True)

# Replace '162+' with '162'
claims_df['PayDelay'] = claims_df['PayDelay'].replace('162+', '162')

# Convert the PayDelay column to numeric values
claims_df['PayDelay'] = pd.to_numeric(claims_df['PayDelay'])

# Apply the mapping to the DSFS column to convert it to numeric
claims_df['DSFS'] = claims_df['DSFS'].map(dsfs_mapping)
claims_df["CharlsonIndex"] = claims_df["CharlsonIndex"].map(charlsonIndex_mapping)

# %%
claims_Y1 = claims_df.loc[claims_df["Year"] == "Y1"]
claims_Y2 = claims_df.loc[claims_df["Year"] == "Y2"]
claims_Y3 = claims_df.loc[claims_df["Year"] == "Y3"]

# %%
claims_Y1
# Out:
#          MemberID  ProviderID    Vendor      PCP Year           Specialty  \
# 0        42286978   8013252.0  172193.0  37796.0   Y1             Surgery
# 6        99829076   6721023.0  265273.0  91972.0   Y1      Rehabilitation
# 7        54666321   9932074.0   35565.0  27294.0   Y1  Diagnostic Imaging
# 11       66951188   4699470.0  179509.0  75876.0   Y1  Diagnostic Imaging
# 12       78859054   9121540.0  523791.0  21579.0   Y1           Emergency
# ...           ...         ...       ...      ...  ...                 ...
# 2668972  98535515   7638907.0  559727.0  83829.0   Y1           Emergency
# 2668975   1344508   4107701.0  164823.0  78718.0   Y1          Laboratory
# 2668977  73820095   1256697.0  789572.0    821.0   Y1             Surgery
# 2668978  22476463   7053364.0  240043.0  70171.0   Y1          Laboratory
# 2668989  57805129   3884005.0  523319.0  90756.0   Y1            Internal
#
#                    PlaceSvc  PayDelay  LengthOfStay  DSFS  \
# 0                    Office        28           0.0   9.0
# 6                    Office       162           0.0   1.0
# 7                    Office        29           0.0   1.0
# 11       Inpatient Hospital        51           0.0   1.0
# 12              Urgent Care        22           1.0   7.0
# ...                     ...       ...           ...   ...
# 2668972         Urgent Care        44           0.0   8.0
# 2668975     Independent Lab        17           0.0   NaN
# 2668977              Office        35           0.0   6.0
# 2668978     Independent Lab        38           0.0   1.0
# 2668989              Office        15           0.0   5.0
#
#         PrimaryConditionGroup  CharlsonIndex ProcedureGroup  SupLOS
# 0                     NEUMENT            0.0            MED       0
# 6                      TRAUMA            0.0            MED       0
# 7                      RESPR4            0.0            RAD       0
# 11                      ROAMI            0.0            RAD       0
# 12                     HEART2            0.0            SDS       0
# ...                       ...            ...            ...     ...
# 2668972                TRAUMA            0.0             EM       0
# 2668975                CATAST            0.0            SCS       0
# 2668977                MSC2a3            2.0            MED       0
# 2668978                MSC2a3            0.0             PL       0
# 2668989                SKNAUT            2.0             EM       0
#
# [865689 rows x 14 columns]

# %%
# Group by 'MemberID' and calculate the mode for each required column
result = claims_Y1.groupby('MemberID').agg({
    'ProviderID': lambda x: x.mode()[0] if not x.mode().empty else None,
    'Vendor': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PCP': lambda x: x.mode()[0] if not x.mode().empty else None,
    'Specialty': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PlaceSvc': lambda x: x.mode()[0] if not x.mode().empty else None,
    'DSFS': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PrimaryConditionGroup': lambda x: x.mode()[0] if not x.mode().empty else None,
    'ProcedureGroup': lambda x: x.mode()[0] if not x.mode().empty else None,
    'SupLOS': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PayDelay': 'mean',           # Calculate the mean for PayDelay
    'LengthOfStay': 'mean',       # Calculate the mean for LengthOfStay
    'CharlsonIndex': 'mean',
    "SupLOS": 'mean'
})

# %%
# Group by 'MemberID' and calculate the mode for each required column
claims_Y2_agg = claims_Y2.groupby('MemberID').agg({
    'ProviderID': lambda x: x.mode()[0] if not x.mode().empty else None,
    'Vendor': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PCP': lambda x: x.mode()[0] if not x.mode().empty else None,
    'Specialty': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PlaceSvc': lambda x: x.mode()[0] if not x.mode().empty else None,
    'DSFS': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PrimaryConditionGroup': lambda x: x.mode()[0] if not x.mode().empty else None,
    'ProcedureGroup': lambda x: x.mode()[0] if not x.mode().empty else None,
    'SupLOS': lambda x: x.mode()[0] if not x.mode().empty else None,
    'PayDelay': 'mean',           # Calculate the mean for PayDelay
    'LengthOfStay': 'mean',       # Calculate the mean for LengthOfStay
    'CharlsonIndex': 'mean',
    "SupLOS": 'mean'
})

# %%
claims_Y2_agg = claims_Y2_agg.reset_index().rename(columns={'index': 'MemberID'})

# %%
claims_Y2_agg
# Out:
#        MemberID  ProviderID    Vendor      PCP         Specialty PlaceSvc  \
# 0             4    994608.0  851052.0  31106.0        Pediatrics   Office
# 1           210   6380938.0  142747.0  37508.0             Other   Office
# 2          3197   7053364.0  122401.0  47016.0        Laboratory   Office
# 3          3457   8321097.0  306597.0  86903.0        Pediatrics   Office
# 4          3713   4686641.0   64835.0  21146.0  General Practice   Office
# ...         ...         ...       ...      ...               ...      ...
# 71430  99985996   3316066.0  726296.0   5300.0          Internal   Office
# 71431  99987030   6374862.0  122401.0  70119.0         Emergency   Office
# 71432  99995391   9777212.0  811200.0  55486.0          Internal   Office
# 71433  99995554   8511459.0   64764.0   1303.0          Internal   Office
# 71434  99998824   4085829.0  240043.0  44164.0         Emergency   Office
#
#        DSFS PrimaryConditionGroup ProcedureGroup  SupLOS   PayDelay  \
# 0       1.0                RESPR4             EM     0.0  43.000000
# 1       1.0                PRGNCY            MED     0.0  51.333333
# 2       2.0                RESPR4             EM     0.0  29.600000
# 3       1.0                MSC2a3             EM     0.0  63.000000
# 4       2.0              ARTHSPIN             EM     0.0  56.200000
# ...     ...                   ...            ...     ...        ...
# 71430   1.0                METAB3             EM     0.0  63.200000
# 71431   1.0                RESPR4             EM     0.0  31.250000
# 71432   3.0               NEUMENT            MED     0.0  48.454545
# 71433   1.0                SKNAUT            MED     0.0  38.733333
# 71434   1.0                MSC2a3             EM     0.0  42.875000
#
#        LengthOfStay  CharlsonIndex
# 0             0.000            0.0
# 1             0.000            0.0
# 2             0.000            0.0
# 3             0.000            0.0
# 4             0.000            0.0
# ...             ...            ...
# 71430         0.000            2.0
# 71431         0.000            0.0
# 71432         0.000            0.0
# 71433         0.000            0.0
# 71434         0.125            0.0
#
# [71435 rows x 13 columns]

# %%
result.to_csv("../data/curated/Claims_Y1.csv", index=False)

# %%
claims_Y2_agg.to_csv("../data/curated/Claims_Y2.csv", index=False)

# %%
drug_count_df["DSFS"].unique()
# Out:
# array(['9-10 months', '8- 9 months', '2- 3 months', '1- 2 months',
#        '10-11 months', '4- 5 months', '6- 7 months', '7- 8 months',
#        '0- 1 month', '3- 4 months', '11-12 months', '5- 6 months'],
#       dtype=object)

# %%
drug_count_df["DrugCount"].unique()
# Out:
# array(['7+', '3', '1', '4', '2', '5', '6'], dtype=object)

# %%
drug_count_df["DSFS"] = drug_count_df["DSFS"].map(dsfs_mapping)

drug_count_df["DrugCount"] = drug_count_df["DrugCount"].replace('7+', '7')
drug_count_df["DrugCount"] = pd.to_numeric(drug_count_df["DrugCount"])

# %%
drug_count_Y1 = drug_count_df[drug_count_df["Year"] == 'Y1']
drug_count_Y2 = drug_count_df[drug_count_df["Year"] == 'Y2']

# %%
drug_count_Y1
# Out:
#         MemberID Year  DSFS  DrugCount
# 2       61221204   Y1     3          1
# 8       30786520   Y1     2          1
# 11      28420460   Y1    11          1
# 12      11861003   Y1     5          1
# 14      66905595   Y1     7          4
# ...          ...  ...   ...        ...
# 818232  61260763   Y1    12          1
# 818234  26018322   Y1     4          1
# 818236  23642577   Y1     6          1
# 818237  99212686   Y1     2          2
# 818239  56710672   Y1     2          3
#
# [281619 rows x 4 columns]

# %%
drug_count_Y1_agg = drug_count_Y1.groupby('MemberID').agg({
    'DSFS': 'mean', 
    'DrugCount': 'sum'
})

# %%
drug_count_Y2_agg = drug_count_Y2.groupby('MemberID').agg({
    'DSFS': 'mean', 
    'DrugCount': 'sum'
})

# %%
drug_count_Y1_agg = drug_count_Y1_agg.reset_index().rename(columns={'index': 'MemberID'})
drug_count_Y2_agg = drug_count_Y2_agg.reset_index().rename(columns={'index': 'MemberID'})

# %%
drug_count_Y1_agg.to_csv("../data/curated/DrugCount_Y1.csv", index = False)
drug_count_Y2_agg.to_csv("../data/curated/DrugCount_Y2.csv", index = False)

# %%
len(result)
# Out:
# 76038

# %%
len(drug_count_Y2_agg)
# Out:
# 46212

# %%
len(claims_Y2_agg)
# Out:
# 71435

# %%
len(days_in_hospital_y3_df)
# Out:
# 71435

# %%
lab_count_df["LabCount"].unique()
# Out:
# array(['1', '2', '6', '4', '5', '3', '8', '10+', '7', '9'], dtype=object)

# %%
lab_count_df["DSFS"] = lab_count_df["DSFS"].map(dsfs_mapping)

lab_count_df["LabCount"] = lab_count_df["LabCount"].replace("10+", "10")

# %%
lab_count_df["LabCount"] = pd.to_numeric(lab_count_df["LabCount"])

# %%
lab_count_Y1 = lab_count_df[lab_count_df["Year"] == "Y1"]
lab_count_Y2 = lab_count_df[lab_count_df["Year"] == "Y2"]

# %%
lab_count_Y1_agg = lab_count_Y1.groupby('MemberID').agg({
    'DSFS': 'mean', 
    'LabCount': 'sum'
})

lab_count_Y1_agg = lab_count_Y1_agg.reset_index().rename(columns={'index': 'MemberID'})

# %%
lab_count_Y2_agg = lab_count_Y2.groupby('MemberID').agg({
    'DSFS': 'mean', 
    'LabCount': 'sum'
})

lab_count_Y2_agg = lab_count_Y2_agg.reset_index().rename(columns={'index': 'MemberID'})

# %%
lab_count_Y1_agg.to_csv("../data/curated/LabCount_Y1.csv", index = False)
lab_count_Y2_agg.to_csv("../data/curated/LabCount_Y2.csv", index = False)

# %%
members_df
# Out:
#         MemberID AgeAtFirstClaim Sex
# 0       14723353           70-79   M
# 1       75706636           70-79   M
# 2       17320609           70-79   M
# 3       69690888           40-49   M
# 4       33004608             0-9   M
# ...          ...             ...  ..
# 112995  99711514           40-49   F
# 112996  31690877           50-59   F
# 112997   9519985           30-39   F
# 112998  92806272           50-59   F
# 112999  81827173           40-49   F
#
# [113000 rows x 3 columns]

# %%
members_df = pd.read_csv("../data/raw/HHP_release3/Members.csv")

# %%
age_mapping = {
    '0-9': 5,
    '10-19': 15,
    '20-29': 25,
    '30-39': 35,
    '40-49': 45,
    '50-59': 55,
    '60-69': 65,
    '70-79': 75,
    '80+': 85,  # Assuming 85 as a representative value for 80+
}

members_df['AgeAtFirstClaim'] = members_df['AgeAtFirstClaim'].map(age_mapping)
median_age = members_df['AgeAtFirstClaim'].median()
members_df["AgeAtFirstClaim"].fillna(median_age, inplace=True)
members_df["Sex"].fillna('N', inplace=True)

# %%
members_df.to_csv("../data/curated/Members.csv", index=False)
